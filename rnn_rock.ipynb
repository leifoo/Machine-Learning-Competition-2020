# %% [markdown]
# # Bidirectional LSTM -- Lei Fu

# %% [markdown]
# * __Author__: _Lei Fu_
# * __Date__: April 26th, 2020

# %% [markdown]
# - <a>0. References</a>
#     - <a> 0.1. Machine Learning for Subsurface Characterization
# - <a>1. Introduction: Synthetic Sonic Curves Generation </a>
#     - <a>1.1. Background</a>
#     - <a>1.2. Problem Statement</a>
#     - <a>1.3. Data Description</a>
#     - <a>1.4. Evaluation Metric</a>
# - <a>2. Imports</a>
# - <a>3. Read in Data</a>
# - <a>4. Glimpse of Data</a>
# - <a>5. Exploratory Data Analysis</a>
# - <a>6. Build Machine Models</a>
# - <a>7. Prediction</a>
# - <a>8. Summary</a>
#
# <a></a>

# %% [markdown]
# ## <a>0. References</a>

# %% [markdown]
# ### <a>0.1. Machine Learning for Subsurface Characterization</a>
#
#     https://books.google.com/books?hl=en&lr=&id=WdO1DwAAQBAJ&oi=fnd&pg=PA1&dq=Unsupervised+Outlier+Detection+Techniques+for+Well+Logs+and+Geophysical+Data&ots=bqx1qdGVIz&sig=6sUAVkNO4yxcD3NhszLhicyMMrc#v=onepage&q&f=false

# %% [markdown]
# ## <a>1. Introduction: Synthetic Sonic Curves Generation</a>

# %% [markdown]
# ### <a>1.1. Background</a>
# Well logs are interpreted/processed to estimate the in-situ petrophysical and geomechanical properties, which is essential for subsurface characterization. Various types of logs exist, and each provides distinct information about subsurface properties. Certain well logs, like gamma ray (GR), resistivity, density, and neutron logs, are considered as “easy-to-acquire” conventional well logs that are run in most of the wells. Other well logs, like nuclear magnetic resonance, dielectric dispersion, elemental spectroscopy, and sometimes sonic logs, are only run in limited number of wells.
#
# Sonic travel-time logs contain critical geomechanical information for subsurface characterization around the wellbore. Often, sonic logs are required to complete the well-seismic tie workflow or geomechanical properties prediction. When sonic logs are absent in a well or an interval, a common practice is to synthesize them based on its neighboring wells that have sonic logs. This is referred to as sonic log synthesis or pseudo sonic log generation.

# %% [markdown]
# ### <a>1.2. Problem Statement</a>
# Compressional travel-time (DTC) and shear travel-time (DTS) logs are not acquired in all the wells drilled in a field due to financial or operational constraints. Under such circumstances, machine learning techniques can be used to predict DTC and DTS logs to improve subsurface characterization. The goal of the “SPWLA’s 1st Petrophysical Data-Driven Analytics Contest” is to develop data-driven models by processing “easy-to-acquire” conventional logs from Well #1, and use the data-driven models to generate synthetic compressional and shear travel-time logs (DTC and DTS, respectively) in Well #2. A robust data-driven model for the desired sonic-log synthesis will result in low prediction errors, which can be quantified in terms of Root Mean Squared Error by comparing the synthesized and the original DTC and DTS logs.
#
# You are provided with two datasets: train.csv and test.csv. You need to build a generalizable data-driven models using train dataset. Following that, you will deploy the newly developed data-driven models on test dataset to predict DTS and DTC logs. The data-driven model should use feature sets derived from the following 7 logs: Caliper, Neutron, Gamma Ray, Deep Resistivity, Medium Resistivity, Photo-electric factor and density. The data-driven model should synthesize two target logs: DTC and DTS logs.
#
# The predicted values should be in the same format as sample_submission.csv, and submit together with your notebook for evaluation.

# %% [markdown]
# ### <a>1.3. Data Decription</a>
# #### Files
# &gt; #### train.csv
# All the values equals to -999 are marked as missing values.
# - CAL - Caliper, unit in Inch,
# - CNC - Neutron, unit in dec
# - GR - Gamma Ray, unit in API
# - HRD - Deep Resisitivity, unit in Ohm per meter,
# - HRM - Medium Resistivity, unit in Ohm per meter,
# - PE - Photo-electric Factor, unit in Barn,
# - ZDEN - Density, unit in Gram per cubit meter,
# - DTC - Compressional Travel-time, unit in nanosecond per foot,
# - DTS - Shear Travel-time, unit in nanosecond per foot,
#
#
# &gt; #### test.csv
# The test data has all features that you used in the train dataset, except the two sonic curves DTC and DTS.
#
# &gt; ####  sample_submission.csv
# A valid sample submission.
# <p><font style="">
# </font></p>

# %% [markdown]
# ### <a>1.4. Evaluation Metric</a>
# We will be evaluated by the metirc `Root Mean Squared Error`.
#
# The RMSE is calculated as:
#
# $ ϵ=∑_i \sqrt{ ∑_n (y_p - y_t)^2 /n } $
#
# Where:
# - y_p is the predicted curve for DTC and DTS
# - y_t is the true value for evaluation.
#
# DTC and DTS are in the same weight during the evaluation
#
# Understanding and optimizing your predictions for this evaluation metric is paramount for this compeition.

# %% [markdown]
# ## <a>2. Imports</a>

# %% [markdown]
# <a>Top</a>

# %%
# import libraries
import pandas as pd
import numpy as np

np.random.seed(7)

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
# import sklearn libararies
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression 
from sklearn.neural_network import MLPRegressor
import matplotlib.style as style

from scipy import stats
from sklearn import svm
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

import tensorflow as tf

tf.random.set_seed(1234)

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)

# Use some functions from tensorflow_docs
# pip install -q git+https://github.com/tensorflow/docs
    
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
from datetime import datetime

style.available

style.use('seaborn-dark')
# plt.style.use('ggplot')
# Out:
# 2.0.0

# %% [markdown]
# ## <a>3. Read Data</a>

# %% [markdown]
# <a>Top</a>

# %%
DROP_FEATURE = ['CAL','HRD','HRM','PE'] # DROP features
# DROP_FEATURE = ['CAL','HRD','HRM','PE']
REPLACE_ANOMALY = True

df1 = pd.read_csv('train.csv')
print(df1.isnull().sum(axis = 0))

print(df1.head())

# df1 = df1.iloc[20000:, :]
# df1.index = np.arange(0,len(df1.index))

start_well2 = 11000
start_well3 = 19939

x_start, x_end = 2500, 15500

plt.figure()
sb.pairplot(df1[['CNC', 'GR', 'ZDEN', 'DTC']])

plt.scatter(df1['CNC'], df1['GR'], s=20, alpha=0.2)

plt.figure()
plt.plot(df1['CAL'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['CNC'])
plt.ylim([0, 2])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['GR'])
# plt.ylim([0, 2])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['HRD'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['HRM'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['PE'])
plt.ylim([0, 50])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['ZDEN'])
plt.ylim([0, 10])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['DTC'])
# plt.ylim([0, 10])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['DTS'])
# plt.ylim([0, 10])
plt.xlim([x_start, x_end])

df1.drop(DROP_FEATURE, axis=1, inplace=True)
    
# print(df1['PE'][19939:].describe())
# df1['PE'][19939:] = df1['PE'][19939:] *100
# print(df1['PE'][19939:].describe())
# print(df1['PE'][:19939].describe())
# print(df1[df1.index == 19938].describe())
# print(df1.tail())

print(df1.head())
# plt.scatter(df1['DTC'], df1['DTS'], s=10, alpha=0.5)
# plt.axis((0,200,0,500))
# Out:
# CAL     0
# CNC     0
# GR      0
# HRD     0
# HRM     0
# PE      0
# ZDEN    0
# DTC     0
# DTS     0
# dtype: int64
#      CAL    CNC       GR    HRD    HRM     PE   ZDEN       DTC       DTS
# 0 -999.0 -999.0  41.4699 -999.0 -999.0 -999.0 -999.0  128.0737  319.0654
# 1 -999.0 -999.0  42.5053 -999.0 -999.0 -999.0 -999.0  127.8347  318.7825
# 2 -999.0 -999.0  43.1548 -999.0 -999.0 -999.0 -999.0  127.2307  317.3323
# 3 -999.0 -999.0  43.2410 -999.0 -999.0 -999.0 -999.0  126.2917  313.6486
# 4 -999.0 -999.0  40.3218 -999.0 -999.0 -999.0 -999.0  125.3985  307.8903
#      CNC       GR   ZDEN       DTC       DTS
# 0 -999.0  41.4699 -999.0  128.0737  319.0654
# 1 -999.0  42.5053 -999.0  127.8347  318.7825
# 2 -999.0  43.1548 -999.0  127.2307  317.3323
# 3 -999.0  43.2410 -999.0  126.2917  313.6486
# 4 -999.0  40.3218 -999.0  125.3985  307.8903

# %% [markdown]
# ## <a>4. Glimps Data</a>

# %% [markdown]
# <a>Top</a>

# %%
df1.describe()
# Out:
#                 CNC            GR          ZDEN           DTC           DTS
# count  30143.000000  30143.000000  30143.000000  30143.000000  30143.000000
# mean     -23.692615     38.959845    -20.229982    -54.891703     -9.737567
# std      157.142679    108.504554    148.809506    372.858812    440.314119
# min     -999.000000   -999.000000   -999.000000   -999.000000   -999.000000
# 25%        0.122800     17.248750      2.226700     66.304350    118.534350
# 50%        0.193600     36.821800      2.432200     78.355100    137.689300
# 75%        0.337150     58.346150      2.551350    107.022500    182.973150
# max     3490.158200   1470.253400      3.259700    155.980300    487.438400

# %%
df1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30143 entries, 0 to 30142
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CNC     30143 non-null  float64
#  1   GR      30143 non-null  float64
#  2   ZDEN    30143 non-null  float64
#  3   DTC     30143 non-null  float64
#  4   DTS     30143 non-null  float64
# dtypes: float64(5)
# memory usage: 1.1 MB

# %% [markdown]
# ## <a>5. Exploratory Data Analysis</a>

# %% [markdown]
# <a>Top</a>

# %% [markdown]
# Exploratory Data Analysis (EDA) is an open-ended process where we calculate statistics and make figures to find trends, missing values, outliers, anomalies, patterns, or relationships within the data.

# %%
# Replace all -999 with nan value
df1.replace(['-999', -999], np.nan, inplace=True)
print(df1.isnull().sum(axis = 0))
df1.describe()
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.683437     47.780541      2.393818     91.814381    180.655730
# std       30.689679     51.377519      0.196276     24.337910     81.141960
# min       -0.102800     -0.146000     -1.923800     49.970500     80.580400
# 25%        0.127100     18.026100      2.234800     71.357000    129.446625
# 50%        0.198500     37.082200      2.439600     85.237600    144.593050
# 75%        0.343100     58.532800      2.553000    112.112600    191.475125
# max     3490.158200   1470.253400      3.259700    155.980300    487.438400

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 9.0)

# Plot well logs
def log_plot(z, log, x_label='', y_label='Sample', title='', lineWidth=1):
    plt.plot(log, z, linewidth=lineWidth)
    plt.ylim(z.max(), z.min())
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.tick_params(labeltop=True, labelright=True)
    plt.grid(b=None, which='both', axis='y')
    
# Plot well logs
def log_plot2(z, log, x_label='Sample', y_label='', title='', lineWidth=1):
    plt.plot(z, log, linewidth=lineWidth)
    plt.xlim(z.min(), z.max())
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.tick_params(labeltop=True, labelright=True)
    plt.grid(b=None, which='both', axis='y')

# %%
# load test data from well 2
df2 = pd.read_csv('test.csv')

print(df2.isnull().sum(axis = 0), df2.shape)

# Remove missing 
for col in df2.columns.tolist():
    df2[col][df2[col]==-999] = np.nan

df2.dropna(axis=0, inplace=True)
df2.describe()
# Out:
# CAL     0
# CNC     0
# GR      0
# HRD     0
# HRM     0
# PE      0
# ZDEN    0
# dtype: int64 (11088, 7)
#                 CAL           CNC            GR           HRD           HRM  \
# count  11088.000000  11088.000000  11088.000000  11088.000000  11088.000000
# mean       8.634049      0.158501     28.966414      4.028372    106.752210
# std        0.044064      0.091298     43.648163      7.198112   2374.620246
# min        8.500000      0.009800      0.852000      0.083900      0.102700
# 25%        8.625000      0.091700      8.449450      1.760775      1.865575
# 50%        8.625000      0.128300     18.168650      2.758900      3.176950
# 75%        8.671900      0.213500     36.470725      4.539675      5.034600
# max        8.875000      0.559400   1124.442000    202.233000  62290.769500
#
#                  PE          ZDEN
# count  11088.000000  11088.000000
# mean       7.353522      2.475884
# std        1.239075      0.149440
# min        4.760800      2.033400
# 25%        6.528075      2.378175
# 50%        7.881700      2.533600
# 75%        8.308325      2.581800
# max       13.840700      3.024800

# %%
df1_orig = df1.copy()

# %%
# Insert index as depth column
# df1.insert(0, 'DEP', df1.index) 

ilog = 2 # ['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 'ZDEN', 'DTC', 'DTS']

# Plot 1 - before vs DTC/DTS, 2 - before vs after, 3 - after vs DTC/DTS 
compare = 3

logs = df1.columns.tolist()
item = logs[ilog]

anomaly = pd.DataFrame(columns=df1.columns)

# Interpolate values out of range
def interpolateValue(item, maxVal, minVal = float('-inf'), df=df1, df_orig=df1_orig):
    ind = ((df_orig[item] > maxVal) | (df_orig[item] < minVal))
    df.loc[ind,item] = np.nan
    
    # print(df[ind == True].index, df[ind][item])
    
    for i,x in enumerate(ind):
        if x:
            j = i + 1
            while ind[j]:
                j += 1
            df.iloc[i-1:j+1] = df.iloc[i-1:j+1].interpolate()
    
    # print(df[ind == True].index, df[ind][item])
    return df_orig.loc[ind, item]

print(df1.isnull().sum(axis = 0))

if item == 'CAL':
    pass
elif item == 'CNC':
    # print(df1[ind == True].index, df1[ind][item])
    anomaly = interpolateValue(item, 0.9)
    # print(df1[ind == True].index, df1[ind][item])
    # print(df1.isnull().sum(axis = 0))
elif item == 'GR':
    anomaly = interpolateValue(item, 400)
elif item == 'HRD':
    anomaly = interpolateValue(item, 250)
elif item == 'HRM':
    anomaly = interpolateValue(item, 500)
elif item == 'PE':
    anomaly = interpolateValue(item, 25)
elif item == 'ZDEN':
    anomaly = interpolateValue(item, 3.1, 1.8)
    
# Plot 1 - before vs DTC/DTS, 2 - before vs after, 3 - after vs DTC/DTS 
plt.subplots(nrows=2, ncols=2, figsize=(16,9))

plt.subplot(2, 1, 1)
if compare == 3:
#     log_plot2(df2.index+len(df1.index)-len(df2.index), df2[item])
    log_plot2(df1.index, df1[item], item, title=item)
else:
    plt.scatter(anomaly.index, anomaly,
                c='red', marker='o', s=20, alpha=0.5)
    log_plot2(df1_orig.index, df1_orig[item], item, title=item)

plt.subplot(2, 1, 2)
if compare == 2:
    log_plot2(df1.index, df1[item], item, title=item)
else:
    plt.subplot(2, 1, 2)
    log_plot2(df1.index, df1['DTC'], 'DTC')
    log_plot2(df1.index, df1['DTS'], 'DTS', title='DTC & DTS')

plt.figure()
plt.scatter(anomaly.index, anomaly, label="anomalies")
plt.title(item + " anomalies")

print(anomaly.describe())
print(df1.isnull().sum(axis = 0))

# plt.figure()
# plt.plot(df1['PE'][19938:19940])
# print(df1['PE'][19939:].describe())
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
# count    121.000000
# mean       1.235612
# std        0.768926
# min       -1.923800
# 25%        0.978900
# 50%        1.353400
# 75%        1.712800
# max        3.259700
# Name: ZDEN, dtype: float64
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
# /home/lei/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
endPoint = 30000
i = 1
ymax = [0, 1, 0, 20, 20, 0, 0]

fig, ax1 = plt.subplots()

color = 'tab:orange'
ax1.set_xlabel('point')
ax1.set_ylabel('DTS/DTC', color=color)
ax1.plot(df1.index[:endPoint], df1['DTS'][:endPoint]/df1['DTC'][:endPoint], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(logs[i], color=color)  # we already handled the x-label with ax1
ax2.plot(df1.index[:endPoint], df1[logs[i]][:endPoint], color=color)
ax2.tick_params(axis='y', labelcolor=color)
if ymax[i]:
    ax2.set_ylim([0, ymax[i]])

fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.figure()
plt.plot(df2[logs[i]][:endPoint])
if ymax[i]:
    plt.ylim([0, ymax[i]])

plt.figure()
plt.plot(df2[logs[i]][1980:2030])
    
# plt.figure()
# df3 = pd.read_csv('real_result_20perc.csv')
# plt.plot(df3['DTS'][:endPoint]/df3['DTC'][:endPoint])

# %%
i = 2

plt.figure()
plt.subplots(nrows=2, ncols=2, figsize=(16,9))
plt.subplot(2, 1, 1)
plt.plot(df2[logs[i]])
plt.plot(df1_orig.index[19939:]-19939, df1_orig[logs[i]][19939:])
plt.title(logs[i])
plt.xlim([0, len(df2.index)])
# plt.ylim([0, 500])

plt.subplot(2, 1, 2)
plt.plot(df1_orig.index[19939:]-19939, df1_orig['DTC'][19939:])
plt.plot(df1_orig.index[19939:]-19939, df1_orig['DTS'][19939:])
plt.xlim([0, len(df2.index)])
# Out:
# (0, 11088)

# %%
if REPLACE_ANOMALY:
    print(df1.isnull().sum(axis = 0))
    print(df1.describe())

    for item in logs[:-2]:
        if item == 'CAL':
            pass
        elif item == 'CNC':
            anomaly = interpolateValue(item, 0.9)
        elif item == 'GR':
            anomaly = interpolateValue(item, 400)
        elif item == 'HRD':
            anomaly = interpolateValue(item, 25)
        elif item == 'HRM':
            anomaly = interpolateValue(item, 25)
        elif item == 'PE':
            anomaly = interpolateValue(item, 25)
        elif item == 'ZDEN':
            anomaly = interpolateValue(item, 3.1, 1.8)

    print(df1.isnull().sum(axis = 0))
    print(df1.describe())
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.683437     47.780541      2.397328     91.814381    180.655730
# std       30.689679     51.377519      0.176521     24.337910     81.141960
# min       -0.102800     -0.146000      1.807900     49.970500     80.580400
# 25%        0.127100     18.026100      2.235100     71.357000    129.446625
# 50%        0.198500     37.082200      2.439600     85.237600    144.593050
# 75%        0.343100     58.532800      2.553000    112.112600    191.475125
# max     3490.158200   1470.253400      3.096600    155.980300    487.438400
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.247720     47.455227      2.397328     91.814381    180.655730
# std        0.155744     47.074419      0.176521     24.337910     81.141960
# min       -0.102800     -0.146000      1.807900     49.970500     80.580400
# 25%        0.126800     18.026100      2.235100     71.357000    129.446625
# 50%        0.198300     37.082200      2.439600     85.237600    144.593050
# 75%        0.342025     58.532800      2.553000    112.112600    191.475125
# max        0.886900    394.813600      3.096600    155.980300    487.438400

# %%
# for i, item in enumerate(logs[-2:]):
#     plt.scatter( df1.index, df1[item], s=2, label=item + ', # of nan = ' + str(df1[item].isna().sum()) )
# plt.legend()

# %%
# fig, ax1 = plt.subplots()

# color = 'tab:red'
# ax1.set_xlabel('point')
# ax1.set_ylabel('CAL', color=color)
# ax1.scatter(df1.index, df1['CAL'], color=color, s=2)
# ax1.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('CNC', color=color)  # we already handled the x-label with ax1
# ax2.scatter(df1.index, df1['CNC'], color=color, s=2)
# ax2.tick_params(axis='y', labelcolor=color)

# fig.tight_layout()  # otherwise the right y-label is slightly clipped

# %%
print(df1.shape)

# remove all rows that contains missing value
df1.dropna(axis=0, inplace=True)

print(df1.shape)

sb.pairplot(df1[['CNC', 'GR', 'ZDEN', 'DTC', 'DTS']])
# Out:
# (30143, 5)
# (20688, 5)

# %%
# Remove outliers
each_feature = False # remove anomalies for each feature
method = 1  # 1-OneClassSVM; 2-IsolationForest; 3-LocalOutlierFactor
outliers_fraction = 1 / 20525

# define outlier/anomaly detection methods to be compared
anomaly_algorithms = [
    ("Robust covariance", EllipticEnvelope(contamination=outliers_fraction)),
    ("One-Class SVM", svm.OneClassSVM(nu=outliers_fraction, kernel="rbf", gamma='scale')),
    ("Isolation Forest", IsolationForest(contamination=outliers_fraction, random_state=42, behaviour="new")),
    ("Local Outlier Factor", LocalOutlierFactor(n_neighbors=35, contamination=outliers_fraction))] # 'auto'))]


# if method == 1:
#     # clf = svm.OneClassSVM(nu=outliers_fraction, gamma=0.1).fit(df1)
#     clf = svm.OneClassSVM(nu=outliers_fraction, gamma='scale').fit(df1[['CNC']])
#     normal = clf.fit_predict(df1[['CNC']])
# elif method == 2:
#     clf = IsolationForest(contamination=outliers_fraction, random_state=42, behaviour="new")
#     normal = clf.fit_predict(df1[['CNC']])
# elif method == 3:
#     clf = LocalOutlierFactor(n_neighbors=35, contamination='auto') #=outliers_fraction)
#     normal = clf.fit_predict(df1[['CNC']])

normal = np.zeros(df1.shape[0], )

print('method = ', method, ': ', anomaly_algorithms[method][0])

if each_feature:
    # detect anomaly for each features
    for i, item in enumerate(logs[:-2]):
        clf = anomaly_algorithms[method][1].fit_predict(df1[[item]])

        plt.figure(figsize=(12.0, 40.0))
        # log_plot(df1.index, df1[item])
        log_plot(df1.index[clf==1], df1[item][clf==1], item, title=item)
        # plt.xlim(0, 1.1)
        print(item, -sum(clf[clf==-1]))

        normal += clf
        
        print(normal.shape)
        
    # remove anamoly
    if method in [0, 1, 2, 3]:
        df1 = df1[normal==df1.shape[1]-2]
        print(df1.shape)
else:
    clf = anomaly_algorithms[method][1].fit_predict(df1)

    for i, item in enumerate(logs):
        plt.figure(figsize=(12.0, 40.0))
        log_plot(df1.index, df1[item])
        log_plot(df1.index[clf==1], df1[item][clf==1], item, title=item)

    print("Number of anomalies = ", -sum(clf[clf==-1]))

    # remove anamoly
    if method in [0, 1, 2, 3]:
        df1 = df1[clf==1]
        print(df1.shape)
# Out:
# method =  1 :  One-Class SVM
# Number of anomalies =  11
# (20677, 5)

# %%
# # Remove outlier by measuring z-score
# z_scores = stats.zscore(df1)
# abs_z_scores = np.abs(z_scores)
# filtered_entries = (abs_z_scores < 5).all(axis=1)
# new_df = df1[filtered_entries]

# new_df.info(verbose=True)

# for i, item in enumerate(logs[:-2]):
#     plt.figure()
#     plt.plot(df1.index, df1[item])
#     plt.plot(new_df.index, new_df[item])
#     plt.title( item + ', # of nan = ' + str(df1[item].isna().sum()) )

# %%
# # Remove DTC >=110
# if False:
#     print(df1.shape)

#     df1= df1[df1["DTC"] < 110]

#     print(df1.shape)

# %%
# df1.columns.tolist()

# %%
# print(df1['DTC'].shape)
# plt.scatter(df1.index, df1['DTC'], s=1)
# plt.title('DTC')

# %%
# plt.scatter(df1.index, df1['CNC'], s=1)

# %%
# plt.scatter(df1.index, df1['CAL'], s=1)
# # plt.title('CAL')

# %%
# # check if there's any co-linearity between features
# # you may check this for all of the features and see if there's any good finding. 
# plt.scatter(df1['CAL'], df1['DTC'], s=10, alpha=0.5)

# %%
# check if there's any co-linearity between features
# you may check this for all of the features and see if there's any good finding. 
plt.scatter(df1['DTC'], df1['DTS'], s=10, alpha=0.5)

# %%
# # another library from Seaborn to check the co-linearity
# sb.pairplot(df1[['ZDEN', 'DTC']])
# # sb.pairplot(df1[['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 'ZDEN', 'DTC', 'DTS']])

# %% [markdown]
# ## <a>6. Build Machine Learning Models</a>

# %% [markdown]
# <a>Top</a>

# %%
def result_plot(y_predict, y_real):
    # check the accuracy of predicted data and plot the result
    print('Root Mean Square Error is:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real, y_predict))))
    print('DTC:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real[:, 0], y_predict[:, 0]))))
    print('DTS:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real[:, 1], y_predict[:, 1]))))
    plt.subplots(nrows=2, ncols=2, figsize=(16,10))
    plt.subplot(2, 2, 1)
    plt.plot(y_real[:, 0])
    plt.plot(y_predict[:, 0])
    plt.legend(['True', 'Predicted'])
    plt.xlabel('Sample')
    plt.ylabel('DTC')
    plt.title('DTC Prediction Comparison')

    plt.subplot(2, 2, 2)
    plt.plot(y_real[:, 1])
    plt.plot(y_predict[:, 1])
    plt.legend(['True', 'Predicted'])
    plt.xlabel('Sample')
    plt.ylabel('DTS')
    plt.title('DTS Prediction Comparison')
    
    plt.subplot(2, 2, 3)
    plt.scatter(y_real[:, 0], y_predict[:, 0])
    plt.xlabel('Real Value')
    plt.ylabel('Predicted Value')
    plt.title('DTC Prediction Comparison')
    
    plt.subplot(2, 2, 4)
    plt.scatter(y_real[:, 1], y_predict[:, 1])
    plt.xlabel('Real Value')
    plt.ylabel('Predicted Value')
    plt.title('DTS Prediction Comparison')

    plt.show()
    
    return np.sqrt(mean_squared_error(y_real, y_predict))

# %%
# Train a binary classifier
print(df1.head())

# Insert label ROCK column
if 'ROCK' not in df1.columns:
    df1.insert(0, 'ROCK', 1)

df1.loc[:, 'ROCK'] = 1
df1.loc[df1.index > 5000, 'ROCK'] = 0 

# plt.subplots(nrows=2, ncols=1, figsize=(16,10))
# plt.subplot(2, 1, 1)
# plt.plot(df1['ROCK'])
# plt.subplot(2, 1, 2)
# plt.plot(df1['DTC'])

# print(len(df1.index))

# split into input (X) and output (y) variables
dataset = np.array(df1)
XData = dataset[:,1:-2]
YData = dataset[:,0]

X, x_test, y, y_test = train_test_split(XData, YData, stratify=YData, test_size=0.25)

# define the keras model
model_bc = keras.Sequential()
model_bc.add(layers.Dense(12, input_dim=len(df1.columns)-3, activation='relu'))
model_bc.add(layers.Dense(8, activation='relu'))
model_bc.add(layers.Dense(1, activation='sigmoid'))

# compile the keras model
model_bc.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000)

if True:
    history = model_bc.fit(
        XData, YData,
        batch_size=5000, epochs=400, 
        verbose=1,
        callbacks=[early_stop, tfdocs.modeling.EpochDots()],
        shuffle=True)
else:
    history = model_bc.fit(
        X, y,
        batch_size=5000, epochs=4000, 
        validation_data=(x_test, y_test), 
#         validation_split = 0.00002,
        verbose=1,
        callbacks=[early_stop, tfdocs.modeling.EpochDots()],
        shuffle=True)
    
    plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
    plotter.plot({'Basic': history}, metric = "accuracy")
    plt.ylabel('accuracy')
    plt.ylim([0,1])
# Out:
#         CNC       GR    ZDEN       DTC       DTS
# 573  0.5173  57.1903  2.3510  125.9611  306.8676
# 574  0.4966  63.1593  2.4055  125.9726  305.8347
# 575  0.4433  64.5217  2.4579  125.8528  305.9089
# 576  0.4309  63.0144  2.4219  125.7362  305.1737
# 577  0.4469  60.8421  2.3138  125.9774  304.4476
# /home/lei/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Train on 20677 samples
# Epoch 1/400
#  5000/20677 [======>.......................] - ETA: 1s - loss: 12.0560 - accuracy: 0.1968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#
# Epoch: 0, accuracy:0.2054,  loss:11.5093,
# 20677/20677 [==============================] - 1s 30us/sample - loss: 11.5093 - accuracy: 0.2054
# Epoch 2/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 10.4784 - accuracy: 0.2186WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 2us/sample - loss: 9.8248 - accuracy: 0.2216
# Epoch 3/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 8.7815 - accuracy: 0.2328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 8.1448 - accuracy: 0.2436
# Epoch 4/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 6.7914 - accuracy: 0.2662WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 6.4580 - accuracy: 0.2757
# Epoch 5/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 5.4110 - accuracy: 0.3110WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 4.8007 - accuracy: 0.3307
# Epoch 6/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 3.6130 - accuracy: 0.3886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 3.1024 - accuracy: 0.4196
# Epoch 7/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 1.8583 - accuracy: 0.4900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 1.3322 - accuracy: 0.5981
# Epoch 8/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4725 - accuracy: 0.7834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4715 - accuracy: 0.8172
# Epoch 9/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.6552 - accuracy: 0.8184WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.6796 - accuracy: 0.8288
# Epoch 10/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.8135 - accuracy: 0.8188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.7834 - accuracy: 0.8288
# Epoch 11/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.7918 - accuracy: 0.8252WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.7525 - accuracy: 0.8288
# Epoch 12/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.7009 - accuracy: 0.8242WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.6412 - accuracy: 0.8288
# Epoch 13/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.5387 - accuracy: 0.8312WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.5008 - accuracy: 0.8288
# Epoch 14/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4138 - accuracy: 0.8342WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4169 - accuracy: 0.8205
# Epoch 15/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4443 - accuracy: 0.7872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4569 - accuracy: 0.7777
# Epoch 16/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4322 - accuracy: 0.7942WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4234 - accuracy: 0.8027
# Epoch 17/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4119 - accuracy: 0.8266WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4131 - accuracy: 0.8288
# Epoch 18/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4209 - accuracy: 0.8288WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4193 - accuracy: 0.8288
# Epoch 19/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3949 - accuracy: 0.8384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4071 - accuracy: 0.8288
# Epoch 20/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3935 - accuracy: 0.8342WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4050 - accuracy: 0.8203
# Epoch 21/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4033 - accuracy: 0.8172WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4043 - accuracy: 0.8184
# Epoch 22/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4005 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.4003 - accuracy: 0.8287
# Epoch 23/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4120 - accuracy: 0.8204WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3995 - accuracy: 0.8288
# Epoch 24/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.4054 - accuracy: 0.8242WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3975 - accuracy: 0.8288
# Epoch 25/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3967 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3961 - accuracy: 0.8287
# Epoch 26/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3996 - accuracy: 0.8254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3946 - accuracy: 0.8287
# Epoch 27/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3899 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3931 - accuracy: 0.8288
# Epoch 28/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3855 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3919 - accuracy: 0.8288
# Epoch 29/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3886 - accuracy: 0.8298WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3902 - accuracy: 0.8288
# Epoch 30/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3827 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3887 - accuracy: 0.8288
# Epoch 31/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3871 - accuracy: 0.8292WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3873 - accuracy: 0.8288
# Epoch 32/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3872 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3857 - accuracy: 0.8288
# Epoch 33/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3817 - accuracy: 0.8300WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3843 - accuracy: 0.8288
# Epoch 34/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3820 - accuracy: 0.8304WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3829 - accuracy: 0.8288
# Epoch 35/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3744 - accuracy: 0.8342WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3812 - accuracy: 0.8288
# Epoch 36/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3904 - accuracy: 0.8230WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 2us/sample - loss: 0.3797 - accuracy: 0.8288
# Epoch 37/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3740 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3781 - accuracy: 0.8288
# Epoch 38/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3815 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3766 - accuracy: 0.8288
# Epoch 39/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3778 - accuracy: 0.8278WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3751 - accuracy: 0.8288
# Epoch 40/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3721 - accuracy: 0.8312WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3735 - accuracy: 0.8288
# Epoch 41/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3737 - accuracy: 0.8292WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3720 - accuracy: 0.8288
# Epoch 42/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3726 - accuracy: 0.8274WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3704 - accuracy: 0.8288
# Epoch 43/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3621 - accuracy: 0.8334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3688 - accuracy: 0.8288
# Epoch 44/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3600 - accuracy: 0.8336WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3672 - accuracy: 0.8288
# Epoch 45/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3689 - accuracy: 0.8264WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3657 - accuracy: 0.8288
# Epoch 46/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3605 - accuracy: 0.8318WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3642 - accuracy: 0.8288
# Epoch 47/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3624 - accuracy: 0.8302WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3625 - accuracy: 0.8288
# Epoch 48/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3549 - accuracy: 0.8348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3611 - accuracy: 0.8288
# Epoch 49/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3515 - accuracy: 0.8358WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3593 - accuracy: 0.8288
# Epoch 50/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3554 - accuracy: 0.8314WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3578 - accuracy: 0.8288
# Epoch 51/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3593 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3561 - accuracy: 0.8288
# Epoch 52/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3419 - accuracy: 0.8386WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3546 - accuracy: 0.8288
# Epoch 53/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3581 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3531 - accuracy: 0.8288
# Epoch 54/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3409 - accuracy: 0.8376WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3515 - accuracy: 0.8288
# Epoch 55/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3474 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3500 - accuracy: 0.8288
# Epoch 56/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3471 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3485 - accuracy: 0.8288
# Epoch 57/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3480 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3469 - accuracy: 0.8288
# Epoch 58/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3509 - accuracy: 0.8250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3452 - accuracy: 0.8288
# Epoch 59/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3545 - accuracy: 0.8216WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3436 - accuracy: 0.8288
# Epoch 60/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3454 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3421 - accuracy: 0.8288
# Epoch 61/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3336 - accuracy: 0.8346WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3405 - accuracy: 0.8288
# Epoch 62/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3387 - accuracy: 0.8278WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3389 - accuracy: 0.8288
# Epoch 63/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3292 - accuracy: 0.8372WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3375 - accuracy: 0.8288
# Epoch 64/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3390 - accuracy: 0.8268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3358 - accuracy: 0.8288
# Epoch 65/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3318 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3344 - accuracy: 0.8288
# Epoch 66/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3353 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3327 - accuracy: 0.8288
# Epoch 67/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3397 - accuracy: 0.8222WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3311 - accuracy: 0.8288
# Epoch 68/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3279 - accuracy: 0.8304WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3296 - accuracy: 0.8288
# Epoch 69/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3134 - accuracy: 0.8386WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3282 - accuracy: 0.8288
# Epoch 70/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3305 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3266 - accuracy: 0.8288
# Epoch 71/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3306 - accuracy: 0.8238WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3250 - accuracy: 0.8288
# Epoch 72/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3293 - accuracy: 0.8254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3237 - accuracy: 0.8288
# Epoch 73/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3256 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3219 - accuracy: 0.8288
# Epoch 74/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3114 - accuracy: 0.8368WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3205 - accuracy: 0.8288
# Epoch 75/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3161 - accuracy: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3189 - accuracy: 0.8288
# Epoch 76/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3154 - accuracy: 0.8318WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3173 - accuracy: 0.8288
# Epoch 77/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3175 - accuracy: 0.8246WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3160 - accuracy: 0.8288
# Epoch 78/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3112 - accuracy: 0.8322WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3146 - accuracy: 0.8288
# Epoch 79/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3144 - accuracy: 0.8290WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3131 - accuracy: 0.8288
# Epoch 80/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3141 - accuracy: 0.8270WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3114 - accuracy: 0.8288
# Epoch 81/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3140 - accuracy: 0.8262WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3101 - accuracy: 0.8288
# Epoch 82/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3094 - accuracy: 0.8290WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3084 - accuracy: 0.8288
# Epoch 83/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3144 - accuracy: 0.8230WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3069 - accuracy: 0.8288
# Epoch 84/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3001 - accuracy: 0.8364WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3055 - accuracy: 0.8288
# Epoch 85/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2943 - accuracy: 0.8376WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3041 - accuracy: 0.8288
# Epoch 86/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3197 - accuracy: 0.8126WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3025 - accuracy: 0.8288
# Epoch 87/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3027 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.3010 - accuracy: 0.8288
# Epoch 88/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.3073 - accuracy: 0.8244WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2996 - accuracy: 0.8288
# Epoch 89/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2933 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2981 - accuracy: 0.8288
# Epoch 90/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2997 - accuracy: 0.8236WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2967 - accuracy: 0.8288
# Epoch 91/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2874 - accuracy: 0.8346WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2953 - accuracy: 0.8288
# Epoch 92/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2914 - accuracy: 0.8318WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2938 - accuracy: 0.8288
# Epoch 93/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2884 - accuracy: 0.8310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2924 - accuracy: 0.8288
# Epoch 94/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2925 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2910 - accuracy: 0.8288
# Epoch 95/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2899 - accuracy: 0.8274WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2895 - accuracy: 0.8288
# Epoch 96/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2907 - accuracy: 0.8246WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2881 - accuracy: 0.8288
# Epoch 97/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2897 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2869 - accuracy: 0.8288
# Epoch 98/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2757 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2853 - accuracy: 0.8288
# Epoch 99/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2843 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2840 - accuracy: 0.8288
# Epoch 100/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2861 - accuracy: 0.8274WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2825 - accuracy: 0.8288
# Epoch 101/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2822 - accuracy: 0.8254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#
# Epoch: 100, accuracy:0.8288,  loss:0.2811,
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2811 - accuracy: 0.8288
# Epoch 102/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2766 - accuracy: 0.8324WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2797 - accuracy: 0.8288
# Epoch 103/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2745 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2783 - accuracy: 0.8288
# Epoch 104/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2699 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2770 - accuracy: 0.8288
# Epoch 105/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2759 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2756 - accuracy: 0.8288
# Epoch 106/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2766 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2742 - accuracy: 0.8288
# Epoch 107/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2771 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2728 - accuracy: 0.8288
# Epoch 108/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2717 - accuracy: 0.8292WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2714 - accuracy: 0.8288
# Epoch 109/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2810 - accuracy: 0.8208WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2704 - accuracy: 0.8289
# Epoch 110/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2762 - accuracy: 0.8228WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2687 - accuracy: 0.8289
# Epoch 111/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2638 - accuracy: 0.8318WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2674 - accuracy: 0.8289
# Epoch 112/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2656 - accuracy: 0.8298WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2661 - accuracy: 0.8291
# Epoch 113/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2661 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2647 - accuracy: 0.8293
# Epoch 114/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2607 - accuracy: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2635 - accuracy: 0.8293
# Epoch 115/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2664 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2625 - accuracy: 0.8297
# Epoch 116/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2628 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2608 - accuracy: 0.8293
# Epoch 117/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2534 - accuracy: 0.8350WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2594 - accuracy: 0.8296
# Epoch 118/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2504 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2582 - accuracy: 0.8306
# Epoch 119/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2543 - accuracy: 0.8346WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2571 - accuracy: 0.8296
# Epoch 120/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2551 - accuracy: 0.8330WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2557 - accuracy: 0.8307
# Epoch 121/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2548 - accuracy: 0.8332WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2544 - accuracy: 0.8313
# Epoch 122/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2554 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2530 - accuracy: 0.8314
# Epoch 123/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2489 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2520 - accuracy: 0.8314
# Epoch 124/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2481 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2506 - accuracy: 0.8310
# Epoch 125/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2448 - accuracy: 0.8354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2493 - accuracy: 0.8352
# Epoch 126/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2523 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2479 - accuracy: 0.8321
# Epoch 127/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2528 - accuracy: 0.8256WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2468 - accuracy: 0.8333
# Epoch 128/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2431 - accuracy: 0.8412WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2454 - accuracy: 0.8374
# Epoch 129/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2428 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2441 - accuracy: 0.8362
# Epoch 130/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2411 - accuracy: 0.8386WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2428 - accuracy: 0.8374
# Epoch 131/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2398 - accuracy: 0.8392WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2415 - accuracy: 0.8390
# Epoch 132/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2415 - accuracy: 0.8356WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2402 - accuracy: 0.8402
# Epoch 133/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2344 - accuracy: 0.8458WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2389 - accuracy: 0.8431
# Epoch 134/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2366 - accuracy: 0.8428WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2377 - accuracy: 0.8405
# Epoch 135/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2294 - accuracy: 0.8482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2365 - accuracy: 0.8422
# Epoch 136/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2366 - accuracy: 0.8472WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2353 - accuracy: 0.8493
# Epoch 137/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2283 - accuracy: 0.8556WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2344 - accuracy: 0.8432
# Epoch 138/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2272 - accuracy: 0.8530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2329 - accuracy: 0.8497
# Epoch 139/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2240 - accuracy: 0.8660WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2317 - accuracy: 0.8526
# Epoch 140/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2288 - accuracy: 0.8596WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2304 - accuracy: 0.8634
# Epoch 141/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2316 - accuracy: 0.8546WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2291 - accuracy: 0.8530
# Epoch 142/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2312 - accuracy: 0.8434WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2281 - accuracy: 0.8502
# Epoch 143/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2308 - accuracy: 0.8560WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2267 - accuracy: 0.8638
# Epoch 144/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2275 - accuracy: 0.8590WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2256 - accuracy: 0.8641
# Epoch 145/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.2261 - accuracy: 0.8684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.2242 - accuracy: 0.8751
# Epoch 146/400
# ...
# Epoch 352/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0667 - accuracy: 0.9870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0637 - accuracy: 0.9886
# Epoch 353/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0614 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0634 - accuracy: 0.9885
# Epoch 354/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0635 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0632 - accuracy: 0.9888
# Epoch 355/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0630 - accuracy: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0628 - accuracy: 0.9887
# Epoch 356/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0633 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0625 - accuracy: 0.9889
# Epoch 357/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0646 - accuracy: 0.9870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0624 - accuracy: 0.9887
# Epoch 358/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0633 - accuracy: 0.9876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0622 - accuracy: 0.9885
# Epoch 359/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0604 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0618 - accuracy: 0.9888
# Epoch 360/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0606 - accuracy: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0615 - accuracy: 0.9888
# Epoch 361/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0604 - accuracy: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0614 - accuracy: 0.9890
# Epoch 362/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0612 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0613 - accuracy: 0.9889
# Epoch 363/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0606 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0610 - accuracy: 0.9882
# Epoch 364/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0614 - accuracy: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0608 - accuracy: 0.9892
# Epoch 365/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0634 - accuracy: 0.9866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0605 - accuracy: 0.9884
# Epoch 366/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0619 - accuracy: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0603 - accuracy: 0.9888
# Epoch 367/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0624 - accuracy: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0598 - accuracy: 0.9889
# Epoch 368/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0637 - accuracy: 0.9870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0595 - accuracy: 0.9887
# Epoch 369/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0599 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0592 - accuracy: 0.9889
# Epoch 370/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0575 - accuracy: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0593 - accuracy: 0.9888
# Epoch 371/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0600 - accuracy: 0.9884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0593 - accuracy: 0.9886
# Epoch 372/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0582 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0587 - accuracy: 0.9889
# Epoch 373/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0590 - accuracy: 0.9904WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0583 - accuracy: 0.9891
# Epoch 374/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0569 - accuracy: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0581 - accuracy: 0.9887
# Epoch 375/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0567 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0578 - accuracy: 0.9890
# Epoch 376/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0578 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0586 - accuracy: 0.9884
# Epoch 377/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0607 - accuracy: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0583 - accuracy: 0.9889
# Epoch 378/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0588 - accuracy: 0.9874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0576 - accuracy: 0.9885
# Epoch 379/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0572 - accuracy: 0.9876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0574 - accuracy: 0.9888
# Epoch 380/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0557 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0573 - accuracy: 0.9888
# Epoch 381/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0574 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0577 - accuracy: 0.9880
# Epoch 382/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0552 - accuracy: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0569 - accuracy: 0.9885
# Epoch 383/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0571 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0563 - accuracy: 0.9890
# Epoch 384/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0527 - accuracy: 0.9918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0560 - accuracy: 0.9891
# Epoch 385/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0549 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0558 - accuracy: 0.9890
# Epoch 386/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0563 - accuracy: 0.9884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 2us/sample - loss: 0.0556 - accuracy: 0.9892
# Epoch 387/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0592 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0554 - accuracy: 0.9889
# Epoch 388/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0553 - accuracy: 0.9910WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0552 - accuracy: 0.9891
# Epoch 389/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0531 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0550 - accuracy: 0.9891
# Epoch 390/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0525 - accuracy: 0.9908WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0548 - accuracy: 0.9887
# Epoch 391/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0543 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0546 - accuracy: 0.9890
# Epoch 392/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0490 - accuracy: 0.9910WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0546 - accuracy: 0.9887
# Epoch 393/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0546 - accuracy: 0.9884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0543 - accuracy: 0.9890
# Epoch 394/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0499 - accuracy: 0.9916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0544 - accuracy: 0.9890
# Epoch 395/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0562 - accuracy: 0.9870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0541 - accuracy: 0.9889
# Epoch 396/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0537 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0540 - accuracy: 0.9890
# Epoch 397/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0509 - accuracy: 0.9886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0537 - accuracy: 0.9891
# Epoch 398/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0554 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0533 - accuracy: 0.9890
# Epoch 399/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0545 - accuracy: 0.9876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0532 - accuracy: 0.9892
# Epoch 400/400
#  5000/20677 [======>.......................] - ETA: 0s - loss: 0.0515 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 20677/20677 [==============================] - 0s 1us/sample - loss: 0.0534 - accuracy: 0.9887

# %%
# convert an array of values into a dataset matrix with zero padding
def create_dataset(dataset, look_back=1, pad=True):
    if pad:
        # dataset_pad = np.pad(dataset, ((look_back, look_back), (0, 0)), mode='constant', constant_values=0)
        dataset_pad = np.pad(dataset, ((look_back, look_back), (0, 0)), mode='edge')
    else:
        dataset_pad = dataset
        
    dataX = []
    for i in range(len(dataset_pad)-2*look_back):
        a = dataset_pad[i:(i+2*look_back+1), :]
        dataX.append(a)
    return np.array(dataX)

# print(df1[df1.index == 19938].describe())
# print(df1.tail())

def moving_average(a, n=5) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
# LSTM
LEARN_RATE = 0.002
TEST_SIZE = 0.00001
EPOCHS = 100
BATCH_SIZE = 500 # None # 1024
PAD_SIZE = 8
TIME_STEPS = 2*PAD_SIZE+1
N_FEATURES = len(df1.columns) - 2

print('LEARN_RATE:', LEARN_RATE, 'TEST_SIZE:', TEST_SIZE, 
      'EPOCHS:', EPOCHS, 'BATCH_SIZE:', BATCH_SIZE, 
      'PAD_SIZE:', PAD_SIZE, 'N_FEATURES:', N_FEATURES)

# seperate the features and targets
df1_data = np.array(df1)
x_trainwell1 = df1_data[:,:-2]
y_trainwell1 = df1_data[:,-2:]

# standize the matrix for training data
scaler = StandardScaler()
x_trainwell1 = scaler.fit_transform(x_trainwell1)

# print(x_trainwell1[:5,:], x_trainwell1[-5:,:])

x_train, x_test, y_train, y_test = train_test_split(x_trainwell1, y_trainwell1, test_size=TEST_SIZE, random_state=100)

if BATCH_SIZE is not None:
    STEPS_PER_EPOCH = len(x_train)//BATCH_SIZE
else: 
    STEPS_PER_EPOCH = 1
    
def build_model():
    model = keras.Sequential([
        layers.Dense(64, # kernel_regularizer=regularizers.l2(0.000),
                     activation='elu', input_shape=[N_FEATURES]),
        layers.BatchNormalization(),
#         layers.Dropout(0.5),
        layers.Dense(64, # kernel_regularizer=regularizers.l2(0.000),
                     activation='elu'),
        layers.BatchNormalization(),
#         layers.Dropout(0.5),
        layers.Dense(64, kernel_regularizer=regularizers.l2(0.000),
                     activation='elu'),
        layers.BatchNormalization(),
#         layers.Dropout(0.5),
        layers.Dense(64, kernel_regularizer=regularizers.l2(0.000),
                     activation='elu'),
        layers.BatchNormalization(),
#         layers.Dropout(0.5),
        layers.Dense(2)
    ])

    lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
        LEARN_RATE,
        decay_steps=STEPS_PER_EPOCH*400,
        decay_rate=1,
        staircase=False)
    
    # optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
    # optimizer = tf.keras.optimizers.Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)
    # optimizer = tf.keras.optimizers.Adamax(lr_schedule, beta_1=0.9, beta_2=0.999)
    # optimizer = tf.keras.optimizers.RMSprop(0.001)
    optimizer = tf.keras.optimizers.Adam(lr_schedule, beta_2=0.999, amsgrad=True)

    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=['mse'])
    return model


model = build_model()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10000)

model.summary()
# print(normed_train_data[:10], )

# example_batch = normed_train_data[:10]
# example_result = model.predict(example_batch)
# example_result

weight = np.ones(len(x_train))
# for i in range(5000):
#     if y_train[i, 0] < 123 and y_train[i, 1] > 250:
#         weight[i] = 4.0

# weight[:5000] = 2.0
# weight[10287:] = 2.0
# weight[10287:12000] = 2.0
# weight[17000:] = 2.0
SAMPLE_WEIGHT = weight
# print(len(moving_average(moving_average(weight, 500), 500)), len(x_train))
# print(SAMPLE_WEIGHT, SAMPLE_WEIGHT[4998:5002])
# print(len(df1[df1.index < 19938]))

np.random.seed(0)

history = model.fit(
    x_train, y_train,
    batch_size=BATCH_SIZE, epochs=EPOCHS, 
#     validation_data=(x_test, y_test), 
    validation_split = 0.00001,
    verbose=1,
    sample_weight=SAMPLE_WEIGHT,
    callbacks=[early_stop, tfdocs.modeling.EpochDots()],
    shuffle=True)
# Out:
# LEARN_RATE: 0.002 TEST_SIZE: 1e-05 EPOCHS: 100 BATCH_SIZE: 500 PAD_SIZE: 8 N_FEATURES: 4
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 13,954
# Trainable params: 13,442
# Non-trainable params: 512
# _________________________________________________________________
# Train on 20675 samples, validate on 1 samples
# Epoch 1/100
# 17500/20675 [========================>.....] - ETA: 0s - loss: 23462.5616 - mse: 23462.5625
# Epoch: 0, loss:23326.3585,  mse:23326.3594,  val_loss:11210.4277,  val_mse:11210.4277,
# 20675/20675 [==============================] - 2s 81us/sample - loss: 23326.3585 - mse: 23326.3594 - val_loss: 11210.4277 - val_mse: 11210.4277
# Epoch 2/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 22178.8944 - mse: 22178.8945 - val_loss: 11655.8154 - val_mse: 11655.8154
# Epoch 3/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 20737.9611 - mse: 20737.9629 - val_loss: 12280.7188 - val_mse: 12280.7188
# Epoch 4/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 19023.9282 - mse: 19023.9258 - val_loss: 13297.3359 - val_mse: 13297.3359
# Epoch 5/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 17176.0806 - mse: 17176.0840 - val_loss: 13515.6611 - val_mse: 13515.6611
# Epoch 6/100
# 20675/20675 [==============================] - 0s 15us/sample - loss: 15284.7452 - mse: 15284.7461 - val_loss: 13313.9199 - val_mse: 13313.9199
# Epoch 7/100
# 20675/20675 [==============================] - 0s 15us/sample - loss: 13332.3450 - mse: 13332.3457 - val_loss: 11277.9199 - val_mse: 11277.9199
# Epoch 8/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 11302.2349 - mse: 11302.2354 - val_loss: 9132.7773 - val_mse: 9132.7773
# Epoch 9/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 9268.8334 - mse: 9268.8320 - val_loss: 9035.9404 - val_mse: 9035.9404
# Epoch 10/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 7360.0105 - mse: 7360.0117 - val_loss: 6409.2930 - val_mse: 6409.2930
# Epoch 11/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 5665.2649 - mse: 5665.2646 - val_loss: 4779.5044 - val_mse: 4779.5044
# Epoch 12/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 4263.1855 - mse: 4263.1860 - val_loss: 3727.3301 - val_mse: 3727.3301
# Epoch 13/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 3127.5533 - mse: 3127.5535 - val_loss: 3129.4871 - val_mse: 3129.4871
# Epoch 14/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 2263.2495 - mse: 2263.2490 - val_loss: 2412.8301 - val_mse: 2412.8301
# Epoch 15/100
# 20675/20675 [==============================] - 0s 15us/sample - loss: 1608.5712 - mse: 1608.5710 - val_loss: 1794.7123 - val_mse: 1794.7123
# Epoch 16/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 1142.5428 - mse: 1142.5427 - val_loss: 1646.2604 - val_mse: 1646.2604
# Epoch 17/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 814.7106 - mse: 814.7106 - val_loss: 1022.0630 - val_mse: 1022.0630
# Epoch 18/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 582.2863 - mse: 582.2863 - val_loss: 745.2073 - val_mse: 745.2073
# Epoch 19/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 430.3436 - mse: 430.3436 - val_loss: 404.5642 - val_mse: 404.5642
# Epoch 20/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 331.2867 - mse: 331.2867 - val_loss: 426.7738 - val_mse: 426.7738
# Epoch 21/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 267.3246 - mse: 267.3246 - val_loss: 227.9385 - val_mse: 227.9385
# Epoch 22/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 225.2936 - mse: 225.2936 - val_loss: 186.0721 - val_mse: 186.0721
# Epoch 23/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 197.6106 - mse: 197.6106 - val_loss: 61.4823 - val_mse: 61.4823
# Epoch 24/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 192.8030 - mse: 192.8030 - val_loss: 213.2780 - val_mse: 213.2780
# Epoch 25/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 182.6151 - mse: 182.6151 - val_loss: 40.4142 - val_mse: 40.4142
# Epoch 26/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 175.8134 - mse: 175.8135 - val_loss: 56.6257 - val_mse: 56.6257
# Epoch 27/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 173.8605 - mse: 173.8605 - val_loss: 119.6592 - val_mse: 119.6592
# Epoch 28/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 166.4659 - mse: 166.4659 - val_loss: 77.2250 - val_mse: 77.2250
# Epoch 29/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 167.1323 - mse: 167.1323 - val_loss: 63.6688 - val_mse: 63.6688
# Epoch 30/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 167.0842 - mse: 167.0842 - val_loss: 46.8949 - val_mse: 46.8949
# Epoch 31/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 163.6412 - mse: 163.6412 - val_loss: 28.8881 - val_mse: 28.8881
# Epoch 32/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 163.2372 - mse: 163.2373 - val_loss: 22.7915 - val_mse: 22.7915
# Epoch 33/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 164.9113 - mse: 164.9114 - val_loss: 30.5529 - val_mse: 30.5529
# Epoch 34/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 168.7759 - mse: 168.7758 - val_loss: 16.4192 - val_mse: 16.4192
# Epoch 35/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 165.3852 - mse: 165.3852 - val_loss: 61.9402 - val_mse: 61.9402
# Epoch 36/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 164.4781 - mse: 164.4781 - val_loss: 55.6954 - val_mse: 55.6954
# Epoch 37/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 163.5013 - mse: 163.5013 - val_loss: 83.8382 - val_mse: 83.8382
# Epoch 38/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 161.3474 - mse: 161.3474 - val_loss: 17.5117 - val_mse: 17.5117
# Epoch 39/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 167.0886 - mse: 167.0886 - val_loss: 25.7995 - val_mse: 25.7995
# Epoch 40/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 162.0537 - mse: 162.0537 - val_loss: 17.9446 - val_mse: 17.9446
# Epoch 41/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 158.7295 - mse: 158.7295 - val_loss: 60.9351 - val_mse: 60.9351
# Epoch 42/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 163.1983 - mse: 163.1983 - val_loss: 4.5164 - val_mse: 4.5164
# Epoch 43/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 163.1732 - mse: 163.1732 - val_loss: 84.3992 - val_mse: 84.3992
# Epoch 44/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 158.1429 - mse: 158.1429 - val_loss: 8.1274 - val_mse: 8.1274
# Epoch 45/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 160.1188 - mse: 160.1188 - val_loss: 50.5334 - val_mse: 50.5334
# Epoch 46/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 157.1012 - mse: 157.1012 - val_loss: 16.9386 - val_mse: 16.9386
# Epoch 47/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 157.6873 - mse: 157.6873 - val_loss: 42.6655 - val_mse: 42.6655
# Epoch 48/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 159.6927 - mse: 159.6927 - val_loss: 18.5573 - val_mse: 18.5573
# Epoch 49/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 162.6808 - mse: 162.6808 - val_loss: 13.4718 - val_mse: 13.4718
# Epoch 50/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 158.2836 - mse: 158.2836 - val_loss: 37.0674 - val_mse: 37.0674
# Epoch 51/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 157.5353 - mse: 157.5353 - val_loss: 32.8032 - val_mse: 32.8032
# Epoch 52/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 159.1691 - mse: 159.1692 - val_loss: 33.6437 - val_mse: 33.6437
# Epoch 53/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 155.9525 - mse: 155.9524 - val_loss: 26.6944 - val_mse: 26.6944
# Epoch 54/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 158.1056 - mse: 158.1056 - val_loss: 5.4952 - val_mse: 5.4952
# Epoch 55/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 160.1565 - mse: 160.1566 - val_loss: 43.4557 - val_mse: 43.4557
# Epoch 56/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 158.8339 - mse: 158.8339 - val_loss: 18.1397 - val_mse: 18.1397
# Epoch 57/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 161.0715 - mse: 161.0715 - val_loss: 67.8675 - val_mse: 67.8675
# Epoch 58/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.6341 - mse: 156.6341 - val_loss: 25.9118 - val_mse: 25.9118
# Epoch 59/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.2456 - mse: 156.2456 - val_loss: 44.4500 - val_mse: 44.4500
# Epoch 60/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 152.9825 - mse: 152.9825 - val_loss: 25.5830 - val_mse: 25.5830
# Epoch 61/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 158.0696 - mse: 158.0696 - val_loss: 11.5017 - val_mse: 11.5017
# Epoch 62/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.1038 - mse: 156.1038 - val_loss: 42.7874 - val_mse: 42.7874
# Epoch 63/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 159.8851 - mse: 159.8851 - val_loss: 14.4572 - val_mse: 14.4572
# Epoch 64/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 153.7829 - mse: 153.7829 - val_loss: 18.8207 - val_mse: 18.8207
# Epoch 65/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 154.1809 - mse: 154.1809 - val_loss: 12.2046 - val_mse: 12.2046
# Epoch 66/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 157.3672 - mse: 157.3672 - val_loss: 6.3047 - val_mse: 6.3047
# Epoch 67/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.6725 - mse: 151.6725 - val_loss: 8.3706 - val_mse: 8.3706
# Epoch 68/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 154.4529 - mse: 154.4529 - val_loss: 25.5922 - val_mse: 25.5922
# Epoch 69/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 157.9226 - mse: 157.9227 - val_loss: 26.8838 - val_mse: 26.8838
# Epoch 70/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.2518 - mse: 156.2518 - val_loss: 20.5674 - val_mse: 20.5674
# Epoch 71/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.1392 - mse: 156.1392 - val_loss: 51.1761 - val_mse: 51.1761
# Epoch 72/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 156.4545 - mse: 156.4545 - val_loss: 34.5116 - val_mse: 34.5116
# Epoch 73/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 153.2469 - mse: 153.2469 - val_loss: 32.0678 - val_mse: 32.0678
# Epoch 74/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.7978 - mse: 151.7978 - val_loss: 35.7149 - val_mse: 35.7149
# Epoch 75/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 155.2482 - mse: 155.2482 - val_loss: 29.1846 - val_mse: 29.1846
# Epoch 76/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 154.0759 - mse: 154.0759 - val_loss: 19.0178 - val_mse: 19.0178
# Epoch 77/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 152.3206 - mse: 152.3206 - val_loss: 7.3356 - val_mse: 7.3356
# Epoch 78/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 154.2195 - mse: 154.2194 - val_loss: 28.7637 - val_mse: 28.7637
# Epoch 79/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 151.1006 - mse: 151.1006 - val_loss: 13.3463 - val_mse: 13.3463
# Epoch 80/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 148.9834 - mse: 148.9834 - val_loss: 25.3563 - val_mse: 25.3563
# Epoch 81/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 149.1470 - mse: 149.1470 - val_loss: 4.0676 - val_mse: 4.0676
# Epoch 82/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 151.9490 - mse: 151.9490 - val_loss: 22.7316 - val_mse: 22.7316
# Epoch 83/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.7526 - mse: 151.7526 - val_loss: 3.7766 - val_mse: 3.7766
# Epoch 84/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 154.0555 - mse: 154.0555 - val_loss: 16.7397 - val_mse: 16.7397
# Epoch 85/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 151.5874 - mse: 151.5874 - val_loss: 26.0419 - val_mse: 26.0419
# Epoch 86/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.9574 - mse: 151.9574 - val_loss: 29.6840 - val_mse: 29.6840
# Epoch 87/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 152.6976 - mse: 152.6976 - val_loss: 10.1786 - val_mse: 10.1786
# Epoch 88/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 149.8159 - mse: 149.8159 - val_loss: 22.7429 - val_mse: 22.7429
# Epoch 89/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 151.3125 - mse: 151.3125 - val_loss: 1.2975 - val_mse: 1.2975
# Epoch 90/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 150.5503 - mse: 150.5503 - val_loss: 21.2428 - val_mse: 21.2428
# Epoch 91/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 154.9006 - mse: 154.9005 - val_loss: 35.5715 - val_mse: 35.5715
# Epoch 92/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 152.6142 - mse: 152.6142 - val_loss: 20.1261 - val_mse: 20.1261
# Epoch 93/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 148.5125 - mse: 148.5125 - val_loss: 9.2005 - val_mse: 9.2005
# Epoch 94/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 150.6565 - mse: 150.6565 - val_loss: 8.0438 - val_mse: 8.0438
# Epoch 95/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 149.3929 - mse: 149.3929 - val_loss: 42.8187 - val_mse: 42.8187
# Epoch 96/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.4810 - mse: 151.4810 - val_loss: 9.2590 - val_mse: 9.2590
# Epoch 97/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 149.6557 - mse: 149.6557 - val_loss: 1.9271 - val_mse: 1.9271
# Epoch 98/100
# 20675/20675 [==============================] - 0s 14us/sample - loss: 147.1125 - mse: 147.1124 - val_loss: 19.0678 - val_mse: 19.0678
# Epoch 99/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.6528 - mse: 151.6528 - val_loss: 8.7391 - val_mse: 8.7391
# Epoch 100/100
# 20675/20675 [==============================] - 0s 13us/sample - loss: 151.5296 - mse: 151.5296 - val_loss: 49.4401 - val_mse: 49.4401

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mse")
plt.ylabel('MSE')
plt.ylim([0,1000])

# check the result on train dataset only
train_predictions = model.predict(x_train)
result_plot(np.array(train_predictions), np.array(y_train))

# # check the result on test dataset only 
# result_plot(model.predict(x_test), y_test)

# check the result on all dataset
y_predict_all = model.predict(x_trainwell1)
result_plot(y_predict_all, y_trainwell1)

# square errors 
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(np.square(np.subtract(y_predict_all[:, 0], y_trainwell1[:, 0]))) 

plt.subplot(2, 1, 2)
plt.plot(np.square(np.subtract(y_predict_all[:, 1], y_trainwell1[:, 1]))) 

plt.figure()
# weight = moving_average(y_train[:, 1], 500)
plt.plot(weight)
# plt.plot(moving_average(moving_average(SAMPLE_WEIGHT, 500), 500))
# Out:
# Root Mean Square Error is: 12.12880
# DTC: 4.20352
# DTS: 16.62967
# Root Mean Square Error is: 12.12854
# DTC: 4.20346
# DTS: 16.62931

# %% [markdown]
# ## <a>7. Prediction</a>

# %% [markdown]
# <a>Top</a>

# %%
# load test data from well 2
df2 = pd.read_csv('test.csv')

# DELETE features
df2.drop(DROP_FEATURE, axis=1, inplace=True)

# Remove missing 
for col in df2.columns.tolist():
    df2[col][df2[col]==-999] = np.nan

df2.dropna(axis=0, inplace=True)
df2_copy = df2.copy()

if REPLACE_ANOMALY:
    for item in logs[:-2]:
        if item == 'CAL':
            pass
        elif item == 'CNC':
            interpolateValue(item, 0.9, df=df2, df_orig=df2_copy)
        elif item == 'GR':
            anomaly = interpolateValue(item, 400, df=df2, df_orig=df2_copy)
        elif item == 'HRD':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'HRM':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'PE':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'ZDEN':
            anomaly = interpolateValue(item, 3.1, 1.8, df=df2, df_orig=df2_copy)

df2_data = np.array(df2)

# predict rock type
predict_rock = model_bc.predict(df2_data)

# predict_rock[0:1991] = .25
# predict_rock[1991:] = .0

shreshold = 0.13
predict_rock2 = predict_rock.copy()
predict_rock2[predict_rock > shreshold] = 1
predict_rock2[predict_rock <= shreshold] = 0

df2_data_bc = np.column_stack((predict_rock2, df2_data)) 
df2_data_bc = scaler.transform(df2_data_bc)
x_trainwell2 = df2_data_bc

# print(x_trainwell2[:5, :], x_trainwell2[-5:, :])

y_trainwell2_predict = model.predict(x_trainwell2)

# load benchmark test data from well 2
df3 = pd.read_csv('real_result_20perc.csv')

# DELETE features
df3.drop(DROP_FEATURE, axis=1, inplace=True)

index = []
print(len(df2.columns))

# Insert index as depth column
df2_sorted = df2_copy
df2_sorted['IND'] = df2_sorted.index

df2_sorted = df2_copy.sort_values(by=[df2_copy.columns[1]])

def binarySearch(target, v):
    beg, end = 0, len(v)-1
    # print(beg, end)
    
    while beg + 1 < end:
        mid = beg + (end - beg) // 2
        
        # print(target, v[mid])
        if v[mid] < target:
            beg = mid
        else:
            end = mid
    
    #  print(target, v[beg], v[end], beg, end)
    if v[beg] == target:
        return beg
    if v[end] == target:
        return end
    return -999

for i, row in df3.iterrows():
    
    row = row.round(4)
    start = binarySearch(row[1].round(4), df2_sorted[df2_copy.columns[1]].round(4).tolist())
    # print('    ', i, start, df2_sorted.iloc[start, 1], row[1])
   
    while df2_sorted.iloc[start, 1].round(4) == row[1]:
        for k in range(len(df2_sorted.columns)-1):
            if row[k] != df2_sorted.iloc[start, k].round(4):
                break
            if k == len(df2_sorted.columns) - 2:
                # print(df2_sorted.iloc[start,-1])
                index.append(df2_sorted.iloc[start,-1])
        start += 1

# print(df3.iloc[0, :])
# print(df2.iloc[index[0], :])
print(len(df3.index), len(index))
if len(df3.index) != len(index):
    raise NameError('index length is wrong!')
    
# check the result
RMSE = result_plot(y_trainwell2_predict[index, :], np.array(df3.iloc[:,-2:]))
print(type(RMSE))

#prediction Plot

y_df3 = np.array(df3.iloc[:,-2:])

plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.plot(y_trainwell2_predict[:,0])

real_data = np.stack((index, y_df3[:, -2]), axis = 1)
real_data_sort = real_data[np.argsort(real_data[:, 0])]
plt.scatter(index, y_df3[:, 0], color='red', s=5)
# plt.plot(real_data_sort[:, 0], real_data_sort[:, 1], color='m')
plt.xlim([0, 2000])

plt.subplot(2, 1, 2)
plt.plot(y_trainwell2_predict[:,1])

real_data = np.stack((index, y_df3[:, -1]), axis = 1)
real_data_sort = real_data[np.argsort(real_data[:, 0])]
plt.scatter(index, y_df3[:, 1], color='red', s=2)
plt.plot(df2_data_bc[:,0]*100)
# plt.plot(real_data_sort[:, 0], real_data_sort[:, 1], color='m')
plt.xlim([0, 2000])

# square errors 
plt.figure()
plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.scatter(index, np.square(np.subtract(y_df3[:, 0], y_trainwell2_predict[index,0]))) 
# plt.xlim([0, 2000])

plt.subplot(2, 1, 2)
plt.scatter(index, np.square(np.subtract(y_df3[:, 1], y_trainwell2_predict[index,1])))
# plt.xlim([0, 2000])

date_time = datetime.now().strftime("%Y%m%d_%H_%M_%S")
rms = np.array2string(RMSE, precision=4)

output_result = pd.DataFrame({'DTC':y_trainwell2_predict[:,0], 'DTS':y_trainwell2_predict[:,1]})
output_result.head()
output_result.to_csv(path_or_buf='./result/'+rms+'-'+'_submission_'+date_time+'.csv', index=False)

# %%
plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.plot(df1_orig['DTC'])
plt.plot(df1.index, df1['DTC'])

plt.subplot(2, 1, 2)
plt.plot(df1_orig['DTS'])
plt.plot(df1.index, df1['DTS'])

# %%
# check if there's any co-linearity between features
plt.scatter(df1_orig['DTC'][:5000], df1_orig['DTS'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1_orig['DTC'][5000:], df1_orig['DTS'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['DTC'][:], df3['DTS'][:], s=20, c='green', alpha=0.2)
plt.xlim([40, 160])
plt.ylim([80, 500])

# %%
plt.scatter(df1['CNC'][:5000], df1['GR'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['CNC'][5000:], df1['GR'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['CNC'], df3['GR'], s=20, c='green', alpha=0.2)
plt.ylim([0, 400])

# %%
plt.scatter(df1['CNC'][:5000], df1['ZDEN'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['CNC'][5000:], df1['ZDEN'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['CNC'], df3['ZDEN'], s=20, c='green', alpha=0.2)
# plt.ylim([0, 500])

# %%
plt.scatter(df1['ZDEN'][:5000], df1['GR'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['ZDEN'][5000:], df1['GR'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['ZDEN'], df3['GR'], s=20, c='green', alpha=0.2)
plt.ylim([0, 400])

# %%
# plot the prediction results 
plt.subplots(nrows=1, ncols=2, figsize=(16,5))
plt.subplot(1, 2, 1)
plt.plot(well2_predict[:, 0])
plt.legend(['Predicted'])
plt.xlabel('Sample')
plt.ylabel('DTC')
plt.title('DTC Prediction Comparison')

plt.subplot(1, 2, 2)
plt.plot(well2_predict[:, 1])
plt.legend(['Predicted'])
plt.xlabel('Sample')
plt.ylabel('DTS')
plt.title('DTS Prediction Comparison')
plt.show()

# %%
# load benchmark test data from well 2
df3 = pd.read_csv('real_result_20perc.csv')

# Remove missing 
for col in df3.columns.tolist():
    df3[col][df3[col]==-999] = np.nan

# Insert index as depth column
# df3.insert(0, 'DEP', df3.index)

# delete features
df3.dropna(DROP_FEATURE, axis=1, inplace=True)

# seperate the features and targets
df3_data = np.array(df3)
y_trainwell3 = df3_data[:,-2:]
x_trainwell3 = df3_data[:,:-2]
x_trainwell3 = scaler.transform(x_trainwell3)
#print(y_trainwell3.head())
print(x_trainwell3[:5][:])

# run the prediction
well3_predict = RF_best.predict(x_trainwell3)
well3_predict[:5, :]

# check the result on test dataset only
result_plot(well3_predict, y_trainwell3)

# %%
output_result = pd.DataFrame({'DTC':well2_predict[:,0], 'DTS':well2_predict[:,1]})
output_result.head()

# %%
#output_result.to_csv(path_or_buf='./sample_submission.csv', index=False)
output_result.to_csv(path_or_buf='./sample_submission2_19.csv', index=False)

# %% [markdown]
# ## <a>8. Summary</a>

# %% [markdown]
# <a>Top</a>

# %% [markdown]
# Put your ideas, findings, insights, suggestions, and references here
